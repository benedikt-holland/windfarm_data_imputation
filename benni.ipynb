# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df.isna().sum()
# Out:
# TurbID         0
# Day            0
# Tmstamp        0
# Wspd       49518
# Wdir       49518
# Etmp       49518
# Itmp       49518
# Ndir       49518
# Pab1       49518
# Pab2       49518
# Pab3       49518
# Prtv       49518
# Patv       49518
# dtype: int64

# %%
df.shape[0]
# Out:
# 4727520

# %%
df.isna().sum()["Prtv"] / df.shape[0]
# Out:
# np.float64(0.010474413646055437)

# %%
df.TurbID.nunique()
# Out:
# 134

# %%
df[df.isna().any(axis=1)].groupby("TurbID").count()
# Out:
#         Day  Tmstamp  Wspd  Wdir  Etmp  Itmp  Ndir  Pab1  Pab2  Pab3  Prtv  \
# TurbID
# 1       362      362     0     0     0     0     0     0     0     0     0
# 2       398      398     0     0     0     0     0     0     0     0     0
# 3       352      352     0     0     0     0     0     0     0     0     0
# 4       355      355     0     0     0     0     0     0     0     0     0
# 5       338      338     0     0     0     0     0     0     0     0     0
# ...     ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 130     350      350     0     0     0     0     0     0     0     0     0
# 131     316      316     0     0     0     0     0     0     0     0     0
# 132     299      299     0     0     0     0     0     0     0     0     0
# 133     294      294     0     0     0     0     0     0     0     0     0
# 134     319      319     0     0     0     0     0     0     0     0     0
#
#         Patv
# TurbID
# 1          0
# 2          0
# ...

# %%
df[df.isna().any(axis=1)].groupby("Day").count()
# Out:
#      TurbID  Tmstamp  Wspd  Wdir  Etmp  Itmp  Ndir  Pab1  Pab2  Pab3  Prtv  \
# Day
# 1       145      145     0     0     0     0     0     0     0     0     0
# 2        16       16     0     0     0     0     0     0     0     0     0
# 3        16       16     0     0     0     0     0     0     0     0     0
# 4        14       14     0     0     0     0     0     0     0     0     0
# 5        15       15     0     0     0     0     0     0     0     0     0
# ..      ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 241      12       12     0     0     0     0     0     0     0     0     0
# 242      26       26     0     0     0     0     0     0     0     0     0
# 243      13       13     0     0     0     0     0     0     0     0     0
# 244      11       11     0     0     0     0     0     0     0     0     0
# 245      13       13     0     0     0     0     0     0     0     0     0
#
#      Patv
# Day
# 1       0
# 2       0
# 3       0
# ...

# %%
df.Day.nunique()
# Out:
# 245

# %%
df[df.isna().any(axis=1)].groupby(["Day", "Tmstamp"]).count().mean()["TurbID"]
# Out:
# np.float64(5.747881601857226)

# %%
df[df.isna().any(axis=1)].groupby(["Day", "Tmstamp"]).count().max()["TurbID"]
# Out:
# np.int64(134)

# %%
df.TurbID.nunique()
# Out:
# 134

# %%
nan = df[df.isna().any(axis=1)]

# %%
days_between_outages = nan.reset_index()["index"] - nan.reset_index().shift()["index"]

# %%
(days_between_outages == 1).sum()
# Out:
# np.int64(40621)

# %%
nan.shape[0]
# Out:
# 49518

# %%
df.head()
# Out:
#    TurbID  Day Tmstamp  Wspd  Wdir   Etmp   Itmp   Ndir  Pab1  Pab2  Pab3  \
# 0       1    1   00:00   NaN   NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1       1    1   00:10  6.17 -3.99  30.73  41.80  25.92   1.0   1.0   1.0
# 2       1    1   00:20  6.27 -2.18  30.60  41.63  20.91   1.0   1.0   1.0
# 3       1    1   00:30  6.42 -0.73  30.52  41.52  20.91   1.0   1.0   1.0
# 4       1    1   00:40  6.25  0.89  30.49  41.38  20.91   1.0   1.0   1.0
#
#    Prtv    Patv
# 0   NaN     NaN
# 1 -0.25  494.66
# 2 -0.24  509.76
# 3 -0.26  542.53
# 4 -0.23  509.36

# %%
df.Patv.hist()
# Out:
# <Axes: >

# %%
df.groupby("TurbID").mean(numeric_only=True)["Patv"].hist()
# Out:
# <Axes: >

# %%
df.isna().any(axis=1).sum() / df.shape[0]
# Out:
# np.float64(0.010474413646055437)

# %%
df.shape[0]
# Out:
# 4727520
